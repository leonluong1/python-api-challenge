# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&apikey={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        #print(city_url)
        city_weather = requests.get(city_url).json()
        #print(json.dumps(city_weather, indent=4))
        #break
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    #break          
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | invercargill
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | remire-montjoly
# Processing Record 5 of Set 1 | palikir - national government center
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | olonkinbyen
# Processing Record 8 of Set 1 | kloulklubed
# Processing Record 9 of Set 1 | nemuro
# Processing Record 10 of Set 1 | taltal
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | west island
# Processing Record 15 of Set 1 | marica
# Processing Record 16 of Set 1 | estrela
# Processing Record 17 of Set 1 | rouissat
# Processing Record 18 of Set 1 | bromolla
# City not found. Skipping...
# Processing Record 19 of Set 1 | bahawalpur
# Processing Record 20 of Set 1 | labasa
# Processing Record 21 of Set 1 | klyuchi
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | goundam
# Processing Record 24 of Set 1 | port mathurin
# Processing Record 25 of Set 1 | tindouf
# Processing Record 26 of Set 1 | tobelo
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | ust-nera
# Processing Record 29 of Set 1 | terrace
# Processing Record 30 of Set 1 | papatowai
# Processing Record 31 of Set 1 | prado
# Processing Record 32 of Set 1 | mizdah
# Processing Record 33 of Set 1 | urangan
# Processing Record 34 of Set 1 | rocha
# Processing Record 35 of Set 1 | vilyuysk
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | iskateley
# Processing Record 38 of Set 1 | tralee
# Processing Record 39 of Set 1 | sinabang
# Processing Record 40 of Set 1 | tazovsky
# Processing Record 41 of Set 1 | ardestan
# Processing Record 42 of Set 1 | chonchi
# Processing Record 43 of Set 1 | utrik
# Processing Record 44 of Set 1 | edinburgh of the seven seas
# Processing Record 45 of Set 1 | poretskoye
# Processing Record 46 of Set 1 | al qaryatayn
# Processing Record 47 of Set 1 | grytviken
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 50 of Set 1 | saipan
# Processing Record 0 of Set 2 | constantia
# Processing Record 1 of Set 2 | iqaluit
# Processing Record 2 of Set 2 | hawaiian paradise park
# Processing Record 3 of Set 2 | ola
# Processing Record 4 of Set 2 | selfoss
# Processing Record 5 of Set 2 | santa vitoria
# Processing Record 6 of Set 2 | gorgan
# Processing Record 7 of Set 2 | bilibino
# Processing Record 8 of Set 2 | kingston
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | dudinka
# Processing Record 13 of Set 2 | choibalsan
# Processing Record 14 of Set 2 | kapuskasing
# Processing Record 15 of Set 2 | whitehorse
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | yashkul'
# Processing Record 18 of Set 2 | puerto natales
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | san luis de la loma
# Processing Record 21 of Set 2 | okha
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | magdagachi
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | blackmans bay
# Processing Record 26 of Set 2 | iwon-up
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | ndikinimeki
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | basoko
# Processing Record 33 of Set 2 | uturoa
# Processing Record 34 of Set 2 | magadan
# Processing Record 35 of Set 2 | jau
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | cururupu
# Processing Record 40 of Set 2 | sydney mines
# Processing Record 41 of Set 2 | kuta
# Processing Record 42 of Set 2 | thinadhoo
# Processing Record 43 of Set 2 | mamuju
# Processing Record 44 of Set 2 | keflavik
# Processing Record 45 of Set 2 | conceicao da barra
# Processing Record 46 of Set 2 | vila franca do campo
# Processing Record 47 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | antonio enes
# Processing Record 0 of Set 3 | suva
# Processing Record 1 of Set 3 | papao
# Processing Record 2 of Set 3 | coxen hole
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | villa gesell
# Processing Record 5 of Set 3 | chadan
# Processing Record 6 of Set 3 | chom bueng
# Processing Record 7 of Set 3 | isle of lewis
# City not found. Skipping...
# Processing Record 8 of Set 3 | tolanaro
# Processing Record 9 of Set 3 | khandyga
# Processing Record 10 of Set 3 | ilulissat
# Processing Record 11 of Set 3 | margaret river
# Processing Record 12 of Set 3 | qaqortoq
# Processing Record 13 of Set 3 | vadso
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | ushuaia
# Processing Record 16 of Set 3 | nouadhibou
# Processing Record 17 of Set 3 | stanley
# Processing Record 18 of Set 3 | hami
# Processing Record 19 of Set 3 | kuala kedah
# Processing Record 20 of Set 3 | la passe
# Processing Record 21 of Set 3 | turpan
# Processing Record 22 of Set 3 | cannonvale
# Processing Record 23 of Set 3 | udachny
# Processing Record 24 of Set 3 | nabire
# Processing Record 25 of Set 3 | orshanka
# Processing Record 26 of Set 3 | novyy urengoy
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | kyshtovka
# Processing Record 29 of Set 3 | aasiaat
# Processing Record 30 of Set 3 | howard springs
# Processing Record 31 of Set 3 | kone
# Processing Record 32 of Set 3 | scunthorpe
# Processing Record 33 of Set 3 | kapa'a
# Processing Record 34 of Set 3 | iquique
# Processing Record 35 of Set 3 | weno
# Processing Record 36 of Set 3 | plettenberg bay
# Processing Record 37 of Set 3 | herkimer
# Processing Record 38 of Set 3 | raduzhny
# Processing Record 39 of Set 3 | takai
# Processing Record 40 of Set 3 | bukama
# Processing Record 41 of Set 3 | constitucion
# Processing Record 42 of Set 3 | pandan
# Processing Record 43 of Set 3 | birao
# Processing Record 44 of Set 3 | natchez
# Processing Record 45 of Set 3 | vinh
# Processing Record 46 of Set 3 | maragogi
# Processing Record 47 of Set 3 | ormara
# Processing Record 48 of Set 3 | flying fish cove
# Processing Record 49 of Set 3 | adelaide
# Processing Record 0 of Set 4 | sao joao da barra
# Processing Record 1 of Set 4 | colac
# Processing Record 2 of Set 4 | san andres
# Processing Record 3 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 4 | mezhova
# Processing Record 5 of Set 4 | bosaso
# Processing Record 6 of Set 4 | hadibu
# Processing Record 7 of Set 4 | vilyuchinsk
# Processing Record 8 of Set 4 | mersing
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | alaghsas
# Processing Record 11 of Set 4 | hobyo
# Processing Record 12 of Set 4 | beykonak
# Processing Record 13 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 4 | lerwick
# Processing Record 15 of Set 4 | lihue
# Processing Record 16 of Set 4 | belmonte
# Processing Record 17 of Set 4 | st. john's
# Processing Record 18 of Set 4 | martapura
# Processing Record 19 of Set 4 | sarangani
# Processing Record 20 of Set 4 | ebon
# Processing Record 21 of Set 4 | peniche
# Processing Record 22 of Set 4 | solleftea
# Processing Record 23 of Set 4 | nova sintra
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | ponta delgada
# Processing Record 26 of Set 4 | moundou
# Processing Record 27 of Set 4 | rongelap
# Processing Record 28 of Set 4 | narrabri
# Processing Record 29 of Set 4 | igarka
# Processing Record 30 of Set 4 | longyearbyen
# Processing Record 31 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 32 of Set 4 | pont rouge
# Processing Record 33 of Set 4 | concepcion
# Processing Record 34 of Set 4 | yuzhno-kurilsk
# Processing Record 35 of Set 4 | yarmouth
# Processing Record 36 of Set 4 | citra
# Processing Record 37 of Set 4 | tamaqua
# Processing Record 38 of Set 4 | elmali
# Processing Record 39 of Set 4 | midvagur
# Processing Record 40 of Set 4 | wailua homesteads
# Processing Record 41 of Set 4 | cocoa beach
# Processing Record 42 of Set 4 | zeya
# Processing Record 43 of Set 4 | naze
# Processing Record 44 of Set 4 | hauterive
# Processing Record 45 of Set 4 | gadzhiyevo
# Processing Record 46 of Set 4 | la libertad
# Processing Record 47 of Set 4 | isafjordur
# Processing Record 48 of Set 4 | vorgashor
# Processing Record 49 of Set 4 | tezu
# Processing Record 0 of Set 5 | bardai
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | letterkenny
# Processing Record 3 of Set 5 | takikawa
# Processing Record 4 of Set 5 | tucumcari
# Processing Record 5 of Set 5 | sitia
# Processing Record 6 of Set 5 | auki
# Processing Record 7 of Set 5 | fortaleza
# Processing Record 8 of Set 5 | atafu village
# Processing Record 9 of Set 5 | tabas
# Processing Record 10 of Set 5 | badger
# Processing Record 11 of Set 5 | moya
# Processing Record 12 of Set 5 | samamiya
# Processing Record 13 of Set 5 | anadyr
# Processing Record 14 of Set 5 | embi
# Processing Record 15 of Set 5 | aljezur
# Processing Record 16 of Set 5 | san clemente del tuyu
# Processing Record 17 of Set 5 | bogotol
# Processing Record 18 of Set 5 | juneau
# Processing Record 19 of Set 5 | aldinga beach
# Processing Record 20 of Set 5 | 'izbat al burj
# City not found. Skipping...
# Processing Record 21 of Set 5 | am timan
# Processing Record 22 of Set 5 | obo
# Processing Record 23 of Set 5 | saksaul'skiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | pathein
# Processing Record 25 of Set 5 | daru
# Processing Record 26 of Set 5 | choma
# Processing Record 27 of Set 5 | berezovyy
# Processing Record 28 of Set 5 | ende
# Processing Record 29 of Set 5 | lembar
# City not found. Skipping...
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | dryden
# Processing Record 32 of Set 5 | bamboo flat
# Processing Record 33 of Set 5 | crescent city
# Processing Record 34 of Set 5 | winnipeg
# Processing Record 35 of Set 5 | sumbawa besar
# Processing Record 36 of Set 5 | minas de marcona
# Processing Record 37 of Set 5 | agat village
# Processing Record 38 of Set 5 | susurluk
# Processing Record 39 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | kerikeri
# Processing Record 42 of Set 5 | grand-bassam
# Processing Record 43 of Set 5 | nogliki
# Processing Record 44 of Set 5 | sisimiut
# Processing Record 45 of Set 5 | nantucket
# Processing Record 46 of Set 5 | holualoa
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | tomball
# Processing Record 49 of Set 5 | tadine
# Processing Record 0 of Set 6 | barra de santo antonio
# Processing Record 1 of Set 6 | adh dhibiyah
# City not found. Skipping...
# Processing Record 2 of Set 6 | san antonio de pale
# Processing Record 3 of Set 6 | saint-yrieix-la-perche
# Processing Record 4 of Set 6 | charters towers
# Processing Record 5 of Set 6 | tinghir
# Processing Record 6 of Set 6 | vicuna
# Processing Record 7 of Set 6 | nar'yan-mar
# Processing Record 8 of Set 6 | wasserburg am inn
# Processing Record 9 of Set 6 | tacuarembo
# Processing Record 10 of Set 6 | yashkino
# Processing Record 11 of Set 6 | meulaboh
# Processing Record 12 of Set 6 | kalamata
# Processing Record 13 of Set 6 | fannuj
# City not found. Skipping...
# Processing Record 14 of Set 6 | mili
# Processing Record 15 of Set 6 | hammerfest
# Processing Record 16 of Set 6 | tosontsengel
# Processing Record 17 of Set 6 | mejit
# Processing Record 18 of Set 6 | acucena
# Processing Record 19 of Set 6 | ventspils
# Processing Record 20 of Set 6 | cascais
# Processing Record 21 of Set 6 | piacabucu
# Processing Record 22 of Set 6 | nadi
# Processing Record 23 of Set 6 | asahikawa
# Processing Record 24 of Set 6 | haiku-pauwela
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | somerset
# Processing Record 27 of Set 6 | phan rang-thap cham
# Processing Record 28 of Set 6 | arawa
# Processing Record 29 of Set 6 | west odessa
# Processing Record 30 of Set 6 | jatiroto
# Processing Record 31 of Set 6 | saint-philippe
# Processing Record 32 of Set 6 | arvika
# Processing Record 33 of Set 6 | bodo
# Processing Record 34 of Set 6 | sabha
# Processing Record 35 of Set 6 | mooloolaba
# Processing Record 36 of Set 6 | rudnya
# Processing Record 37 of Set 6 | nsunga
# Processing Record 38 of Set 6 | kirakira
# Processing Record 39 of Set 6 | shakawe
# Processing Record 40 of Set 6 | igrim
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | blackwater
# Processing Record 43 of Set 6 | sake
# Processing Record 44 of Set 6 | mata-utu
# Processing Record 45 of Set 6 | muncar
# Processing Record 46 of Set 6 | buala
# Processing Record 47 of Set 6 | waynesboro
# Processing Record 48 of Set 6 | takoradi
# Processing Record 49 of Set 6 | kodiak
# Processing Record 0 of Set 7 | arvayheer
# Processing Record 1 of Set 7 | sao felix do xingu
# Processing Record 2 of Set 7 | isla vista
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | chadron
# Processing Record 5 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 6 of Set 7 | kristiansund
# Processing Record 7 of Set 7 | trairi
# Processing Record 8 of Set 7 | sitka
# Processing Record 9 of Set 7 | cockburn town
# Processing Record 10 of Set 7 | bereznik
# Processing Record 11 of Set 7 | lock haven
# Processing Record 12 of Set 7 | louhans
# Processing Record 13 of Set 7 | yartsevo
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | masterton
# Processing Record 16 of Set 7 | lobujya
# Processing Record 17 of Set 7 | baise city
# Processing Record 18 of Set 7 | yemva
# Processing Record 19 of Set 7 | tefe
# Processing Record 20 of Set 7 | polyarnyy
# Processing Record 21 of Set 7 | leck
# Processing Record 22 of Set 7 | port-vila
# Processing Record 23 of Set 7 | n'zeto
# Processing Record 24 of Set 7 | jaru
# Processing Record 25 of Set 7 | bari
# Processing Record 26 of Set 7 | yerofey pavlovich
# Processing Record 27 of Set 7 | buon ma thuot
# Processing Record 28 of Set 7 | alofi
# Processing Record 29 of Set 7 | santa cruz
# Processing Record 30 of Set 7 | farafenni
# Processing Record 31 of Set 7 | susuman
# Processing Record 32 of Set 7 | port elizabeth
# Processing Record 33 of Set 7 | gazojak
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | chazuta
# Processing Record 37 of Set 7 | chabahar
# Processing Record 38 of Set 7 | nadym
# Processing Record 39 of Set 7 | tanjung pinang
# Processing Record 40 of Set 7 | mazamari
# Processing Record 41 of Set 7 | qamdo
# Processing Record 42 of Set 7 | altai
# Processing Record 43 of Set 7 | upington
# Processing Record 44 of Set 7 | luanda
# Processing Record 45 of Set 7 | san luis
# Processing Record 46 of Set 7 | rikaze
# Processing Record 47 of Set 7 | tres arroyos
# Processing Record 48 of Set 7 | kismayo
# Processing Record 49 of Set 7 | cabedelo
# Processing Record 0 of Set 8 | gurupa
# Processing Record 1 of Set 8 | nahiyat al fuhud
# Processing Record 2 of Set 8 | chatra
# Processing Record 3 of Set 8 | kralendijk
# Processing Record 4 of Set 8 | doka
# Processing Record 5 of Set 8 | sussex
# Processing Record 6 of Set 8 | mar del plata
# Processing Record 7 of Set 8 | aqadyr
# Processing Record 8 of Set 8 | tromso
# Processing Record 9 of Set 8 | tiksi
# Processing Record 10 of Set 8 | as sulayyil
# Processing Record 11 of Set 8 | san julian
# Processing Record 12 of Set 8 | east london
# Processing Record 13 of Set 8 | saguenay
# Processing Record 14 of Set 8 | bentiu
# Processing Record 15 of Set 8 | coari
# Processing Record 16 of Set 8 | ceres
# Processing Record 17 of Set 8 | puerto aysen
# Processing Record 18 of Set 8 | marquette
# Processing Record 19 of Set 8 | huilong
# Processing Record 20 of Set 8 | osby
# Processing Record 21 of Set 8 | senanga
# Processing Record 22 of Set 8 | la ronge
# Processing Record 23 of Set 8 | kruisfontein
# Processing Record 24 of Set 8 | arraial do cabo
# Processing Record 25 of Set 8 | horsham
# Processing Record 26 of Set 8 | santa cecilia
# Processing Record 27 of Set 8 | port-gentil
# Processing Record 28 of Set 8 | huaihua
# Processing Record 29 of Set 8 | ulsteinvik
# Processing Record 30 of Set 8 | sabang
# Processing Record 31 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 8 | hotan
# Processing Record 33 of Set 8 | castillos
# Processing Record 34 of Set 8 | abra pampa
# Processing Record 35 of Set 8 | frontera
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | tremp
# Processing Record 38 of Set 8 | edd
# Processing Record 39 of Set 8 | la'ie
# Processing Record 40 of Set 8 | iskushuban
# Processing Record 41 of Set 8 | payyannur
# Processing Record 42 of Set 8 | laayoune
# Processing Record 43 of Set 8 | batie
# Processing Record 44 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | comayagua
# Processing Record 47 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 48 of Set 8 | isiro
# Processing Record 49 of Set 8 | ensisheim
# Processing Record 0 of Set 9 | kidal
# Processing Record 1 of Set 9 | portland
# Processing Record 2 of Set 9 | hualien city
# Processing Record 3 of Set 9 | tra mhor
# Processing Record 4 of Set 9 | el calafate
# Processing Record 5 of Set 9 | kolonia
# Processing Record 6 of Set 9 | fale old settlement
# Processing Record 7 of Set 9 | kovel
# Processing Record 8 of Set 9 | ust'-ilimsk
# Processing Record 9 of Set 9 | novi pazar
# Processing Record 10 of Set 9 | taguatinga
# Processing Record 11 of Set 9 | bayburt
# Processing Record 12 of Set 9 | floro
# Processing Record 13 of Set 9 | ghazni
# Processing Record 14 of Set 9 | lazaro cardenas
# Processing Record 15 of Set 9 | kayangel
# Processing Record 16 of Set 9 | uige
# Processing Record 17 of Set 9 | imperatriz
# Processing Record 18 of Set 9 | nikel
# Processing Record 19 of Set 9 | margate
# Processing Record 20 of Set 9 | jijel
# Processing Record 21 of Set 9 | el daein
# City not found. Skipping...
# Processing Record 22 of Set 9 | queenstown
# Processing Record 23 of Set 9 | lospalos
# Processing Record 24 of Set 9 | cadale
# Processing Record 25 of Set 9 | villa huidobro
# Processing Record 26 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 27 of Set 9 | egilsstadir
# Processing Record 28 of Set 9 | peace river
# Processing Record 29 of Set 9 | altay
# Processing Record 30 of Set 9 | zhanaozen
# Processing Record 31 of Set 9 | porto velho
# Processing Record 32 of Set 9 | jayapura
# Processing Record 33 of Set 9 | gizo
# Processing Record 34 of Set 9 | baoshan
# Processing Record 35 of Set 9 | posto fiscal rolim de moura
# Processing Record 36 of Set 9 | new cairo
# City not found. Skipping...
# Processing Record 37 of Set 9 | gueltat zemmour
# City not found. Skipping...
# Processing Record 38 of Set 9 | muntok
# Processing Record 39 of Set 9 | happy valley-goose bay
# Processing Record 40 of Set 9 | kattivakkam
# Processing Record 41 of Set 9 | sinan
# Processing Record 42 of Set 9 | sanibel
# Processing Record 43 of Set 9 | lodwar
# Processing Record 44 of Set 9 | vieste
# Processing Record 45 of Set 9 | san jose del guaviare
# Processing Record 46 of Set 9 | anta
# Processing Record 47 of Set 9 | shanting
# Processing Record 48 of Set 9 | kultali
# City not found. Skipping...
# Processing Record 49 of Set 9 | xiulin
# Processing Record 0 of Set 10 | albertina
# Processing Record 1 of Set 10 | mazatlan
# Processing Record 2 of Set 10 | shingu
# Processing Record 3 of Set 10 | al burayqah
# Processing Record 4 of Set 10 | padang
# Processing Record 5 of Set 10 | tazacorte
# Processing Record 6 of Set 10 | kendari
# Processing Record 7 of Set 10 | bel ombre
# Processing Record 8 of Set 10 | rabaul
# Processing Record 9 of Set 10 | conduaga
# Processing Record 10 of Set 10 | alpine
# Processing Record 11 of Set 10 | valparaiso
# Processing Record 12 of Set 10 | togur
# Processing Record 13 of Set 10 | luganville
# Processing Record 14 of Set 10 | new norfolk
# Processing Record 15 of Set 10 | ballina
# Processing Record 16 of Set 10 | pisco
# Processing Record 17 of Set 10 | carnarvon
# Processing Record 18 of Set 10 | djibo
# Processing Record 19 of Set 10 | arkadelphia
# Processing Record 20 of Set 10 | wang saphung
# Processing Record 21 of Set 10 | colgong
# Processing Record 22 of Set 10 | callao
# Processing Record 23 of Set 10 | taichung
# Processing Record 24 of Set 10 | cabrero
# Processing Record 25 of Set 10 | baharly
# Processing Record 26 of Set 10 | harstad
# Processing Record 27 of Set 10 | comodoro rivadavia
# Processing Record 28 of Set 10 | flin flon
# Processing Record 29 of Set 10 | puerto armuelles
# Processing Record 30 of Set 10 | den burg
# Processing Record 31 of Set 10 | northam
# Processing Record 32 of Set 10 | ndele
# Processing Record 33 of Set 10 | ad dabbah
# Processing Record 34 of Set 10 | kushiro
# Processing Record 35 of Set 10 | villa presidente frei, nunoa, santiago, chile
# City not found. Skipping...
# Processing Record 36 of Set 10 | matoury
# Processing Record 37 of Set 10 | itoman
# Processing Record 38 of Set 10 | arteche
# Processing Record 39 of Set 10 | seaside
# Processing Record 40 of Set 10 | mount gambier
# Processing Record 41 of Set 10 | amahai
# Processing Record 42 of Set 10 | phirangipuram
# Processing Record 43 of Set 10 | nagqu
# Processing Record 44 of Set 10 | mildura
# Processing Record 45 of Set 10 | westport
# Processing Record 46 of Set 10 | enoch
# Processing Record 47 of Set 10 | greenville
# Processing Record 48 of Set 10 | tanki leendert
# City not found. Skipping...
# Processing Record 49 of Set 10 | palmas de monte alto
# Processing Record 0 of Set 11 | kenai
# Processing Record 1 of Set 11 | enewetak
# Processing Record 2 of Set 11 | jabor
# Processing Record 3 of Set 11 | senador guiomard
# Processing Record 4 of Set 11 | acarau
# Processing Record 5 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 11 | ewing
# Processing Record 7 of Set 11 | joanopolis
# Processing Record 8 of Set 11 | mancora
# Processing Record 9 of Set 11 | alindao
# Processing Record 10 of Set 11 | opuwo
# Processing Record 11 of Set 11 | ta`u
# Processing Record 12 of Set 11 | sorsk
# Processing Record 13 of Set 11 | amga
# Processing Record 14 of Set 11 | zhanibek
# Processing Record 15 of Set 11 | sosua
# Processing Record 16 of Set 11 | nelson bay
# Processing Record 17 of Set 11 | vernon
# Processing Record 18 of Set 11 | nampula
# Processing Record 19 of Set 11 | nyrob
# Processing Record 20 of Set 11 | colonia
# Processing Record 21 of Set 11 | taksimo
# Processing Record 22 of Set 11 | gay
# Processing Record 23 of Set 11 | danilovka
# Processing Record 24 of Set 11 | canutama
# Processing Record 25 of Set 11 | jutai
# Processing Record 26 of Set 11 | sidney
# Processing Record 27 of Set 11 | kiama
# Processing Record 28 of Set 11 | varna
# Processing Record 29 of Set 11 | viedma
# Processing Record 30 of Set 11 | tauranga
# Processing Record 31 of Set 11 | kayyerkan
# Processing Record 32 of Set 11 | whitecourt
# Processing Record 33 of Set 11 | brisas de zicatela
# Processing Record 34 of Set 11 | gashua
# Processing Record 35 of Set 11 | ust-tsilma
# Processing Record 36 of Set 11 | beyla
# Processing Record 37 of Set 11 | tuy hoa
# Processing Record 38 of Set 11 | santo antonio
# Processing Record 39 of Set 11 | zheleznogorsk-ilimskiy
# Processing Record 40 of Set 11 | monrovia
# Processing Record 41 of Set 11 | taoudenni
# Processing Record 42 of Set 11 | piui
# Processing Record 43 of Set 11 | yatou
# Processing Record 44 of Set 11 | monte santo
# Processing Record 45 of Set 11 | santana
# Processing Record 46 of Set 11 | ciudad madero
# Processing Record 47 of Set 11 | bandar-e genaveh
# Processing Record 48 of Set 11 | rio claro
# Processing Record 49 of Set 11 | nyurba
# Processing Record 0 of Set 12 | santa rosa
# Processing Record 1 of Set 12 | qapqal
# City not found. Skipping...
# Processing Record 2 of Set 12 | ostersund
# Processing Record 3 of Set 12 | kuanda
# Processing Record 4 of Set 12 | orsa
# Processing Record 5 of Set 12 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 6 of Set 12 | the pas
# Processing Record 7 of Set 12 | shabqadar
# Processing Record 8 of Set 12 | nuuk
# Processing Record 9 of Set 12 | tynda
# Processing Record 10 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 11 of Set 12 | motygino
# Processing Record 12 of Set 12 | bodaybo
# Processing Record 13 of Set 12 | nguigmi
# Processing Record 14 of Set 12 | minot
# Processing Record 15 of Set 12 | purpe
# Processing Record 16 of Set 12 | luena
# Processing Record 17 of Set 12 | brak
# Processing Record 18 of Set 12 | tual
# Processing Record 19 of Set 12 | yangshuo
# Processing Record 20 of Set 12 | ambon
# Processing Record 21 of Set 12 | nacozari viejo
# Processing Record 22 of Set 12 | vadakku valliyur
# Processing Record 23 of Set 12 | la oliva
# Processing Record 24 of Set 12 | natal
# Processing Record 25 of Set 12 | hilo
# Processing Record 26 of Set 12 | kotabumi
# Processing Record 27 of Set 12 | conception bay south
# Processing Record 28 of Set 12 | faulquemont
# Processing Record 29 of Set 12 | christchurch
# Processing Record 30 of Set 12 | chilliwack
# Processing Record 31 of Set 12 | kirensk
# Processing Record 32 of Set 12 | coahuayana de hidalgo
# Processing Record 33 of Set 12 | serdar
# Processing Record 34 of Set 12 | geraldton
# Processing Record 35 of Set 12 | chibougamau
# Processing Record 36 of Set 12 | cuero
# Processing Record 37 of Set 12 | hede
# Processing Record 38 of Set 12 | belyy yar
# Processing Record 39 of Set 12 | mil'kovo
# Processing Record 40 of Set 12 | olinda
# Processing Record 41 of Set 12 | bogo
# Processing Record 42 of Set 12 | sierra grande
# Processing Record 43 of Set 12 | krasnoural'sk
# Processing Record 44 of Set 12 | ban houayxay
# Processing Record 45 of Set 12 | novodvinsk
# Processing Record 46 of Set 12 | labytnangi
# Processing Record 47 of Set 12 | prince rupert
# Processing Record 48 of Set 12 | fort mcmurray
# Processing Record 49 of Set 12 | sao vicente
# Processing Record 0 of Set 13 | east wenatchee bench
# Processing Record 1 of Set 13 | arrifes
# Processing Record 2 of Set 13 | morant bay
# Processing Record 3 of Set 13 | gornozavodsk
# Processing Record 4 of Set 13 | mogocha
# Processing Record 5 of Set 13 | sayat
# Processing Record 6 of Set 13 | quellon
# Processing Record 7 of Set 13 | yigo village
# Processing Record 8 of Set 13 | beau vallon
# Processing Record 9 of Set 13 | selebi-phikwe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                                    City      Lat       Lng  Max Temp  \
# 0                             adamstown -25.0660 -130.1015     20.17
# 1                          invercargill -46.4000  168.3500      6.68
# 2                                avarua -21.2078 -159.7750     20.03
# 3                       remire-montjoly   4.9167  -52.2667     34.02
# 4  palikir - national government center   6.9248  158.1611     24.41
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        70          98        0.48      PN  1697304681
# 1        79          69        2.24      NZ  1697304585
# 2       100         100        0.51      CK  1697304681
# 3        59          20        5.66      GF  1697304682
# 4        88         100        2.57      FM  1697304682

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data2/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data2/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 0                                   adamstown -25.0660 -130.1015     20.17
# 1                                invercargill -46.4000  168.3500      6.68
# 2                                      avarua -21.2078 -159.7750     20.03
# 3                             remire-montjoly   4.9167  -52.2667     34.02
# 4        palikir - national government center   6.9248  158.1611     24.41
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0              70          98        0.48      PN  1697304681
# 1              79          69        2.24      NZ  1697304585
# 2             100         100        0.51      CK  1697304681
# 3              59          20        5.66      GF  1697304682
# 4              88         100        2.57      FM  1697304682

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_col = city_data_df["Lat"]
temp_col = city_data_df["Max Temp"]
plt.scatter(lat_col, temp_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_col = city_data_df["Lat"]
humid_col = city_data_df["Humidity"]
plt.scatter(lat_col, humid_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_col = city_data_df["Lat"]
cloud_col = city_data_df["Cloudiness"]
plt.scatter(lat_col, cloud_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_col = city_data_df["Lat"]
wind_col = city_data_df["Wind Speed"]
plt.scatter(lat_col, wind_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_regress(df, col1, col2, xycoords="axes fraction", xy = (0.16, 0.12), xlabel="", ylabel=""):
    x = df[col1]
    y = df[col2]
    plt.scatter(x, y, c="y")
    xlabel = col1 if xlabel == "" else xlabel 
    ylabel = col2 if ylabel == "" else ylabel 
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    regress_values = slope*x + intercept
    plt.plot(x, regress_values, c="r")
    plt.annotate(f"y = {round(slope, 2)} + {round(intercept, 2)}", xy=xy, xycoords=xycoords, c="black", size=14)
    print(f"The r-value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                                          City      Lat       Lng  Max Temp  \
# City_ID
# 3                             remire-montjoly   4.9167  -52.2667     34.02
# 4        palikir - national government center   6.9248  158.1611     24.41
# 6                                 olonkinbyen  70.9221   -8.7187     -2.30
# 7                                 kloulklubed   7.0419  134.2556     26.28
# 8                                      nemuro  43.3236  145.5750     14.05
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 3              59          20        5.66      GF  1697304682
# 4              88         100        2.57      FM  1697304682
# 6              86         100        9.88      SJ  1697304683
# 7              77          62        3.80      PW  1697304683
# 8              71         100        3.28      JP  1697304601

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           adamstown -25.0660 -130.1015     20.17        70          98
# 1        invercargill -46.4000  168.3500      6.68        79          69
# 2              avarua -21.2078 -159.7750     20.03       100         100
# 5            waitangi -43.9535 -176.5597     12.68        92          35
# 9              taltal -25.4000  -70.4833     19.68        61          10
#
#          Wind Speed Country        Date
# City_ID
# 0              0.48      PN  1697304681
# 1              2.24      NZ  1697304585
# 2              0.51      CK  1697304681
# 5              4.02      NZ  1697304547
# 9              3.79      CL  1697304684

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_regress(northern_hemi_df, "Lat", "Max Temp", xlabel="Latitude")
# Out:
# The r-value is: -0.869862366422315

# %%
# Linear regression on Southern Hemisphere
plot_regress(southern_hemi_df, "Lat", "Max Temp", xlabel="Latitude")
# Out:
# The r-value is: 0.779544570047579

# %% [markdown]
# **Discussion about the linear relationship:** The northern hemisphere has a strong negative correlation between temperature and latitude.
# The southern hemisphere has a strong positive correlation between temperature and latitude.
# Another way to say this is temperatures increase as you get closer to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_regress(northern_hemi_df, "Lat", "Humidity", xlabel="Latitude", xy=(0.5, 0.12))
# Out:
# The r-value is: 0.1983005833713392

# %%
# Southern Hemisphere
plot_regress(southern_hemi_df, "Lat", "Humidity", xlabel="Latitude", xy=(0.03, 0.34))
# Out:
# The r-value is: 0.10941275334268492

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres have a weak positive correlation between Latitude and Humidity. This means that latitude does not affect humidity that much.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_regress(northern_hemi_df, "Lat", "Cloudiness", xlabel="Latitude", xy=(0.65, 0.5))
# Out:
# The r-value is: 0.24069083903954921

# %%
# Southern Hemisphere
plot_regress(southern_hemi_df, "Lat", "Cloudiness", xlabel="Latitude", xy=(0.50, 0.42))
# Out:
# The r-value is: 0.13819383093897214

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres have a weak positive correlation between Latitude and Cloudiness. This means that latitude does not affect cloudiness that much.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_regress(northern_hemi_df, "Lat", "Wind Speed", xlabel="Latitude")
# Out:
# The r-value is: 0.28776220868005054

# %%
# Southern Hemisphere
plot_regress(southern_hemi_df, "Lat", "Wind Speed", xlabel="Latitude", xy=(0.08, 0.32))
# Out:
# The r-value is: -0.2610706162020809

# %% [markdown]
# **Discussion about the linear relationship:** The northern hemisphere has a weak-to-moderate positive correlation between temperature and wind speed. The southern hemisphere has a weak negative correlation between temperature and wind speed. Another way to say this is wind speeds slightly decrease as you get closer to the equator.
