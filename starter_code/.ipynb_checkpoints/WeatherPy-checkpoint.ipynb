# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&apikey={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        #print(city_url)
        city_weather = requests.get(city_url).json()
        #print(json.dumps(city_weather, indent=4))
        #break
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    #break          
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | mukah
# City not found. Skipping...
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | matoury
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | jiagedaqi
# Processing Record 9 of Set 1 | invercargill
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | la passe
# Processing Record 15 of Set 1 | west island
# Processing Record 16 of Set 1 | mount pearl
# Processing Record 17 of Set 1 | motueka
# Processing Record 18 of Set 1 | rongelap
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | balsas
# Processing Record 21 of Set 1 | hammerfest
# Processing Record 22 of Set 1 | ak-suu
# Processing Record 23 of Set 1 | kapuskasing
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | zaozersk
# Processing Record 26 of Set 1 | codrington
# Processing Record 27 of Set 1 | techiman
# Processing Record 28 of Set 1 | grytviken
# Processing Record 29 of Set 1 | port-aux-francais
# Processing Record 30 of Set 1 | labytnangi
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | margaret river
# Processing Record 33 of Set 1 | pandan
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | flying fish cove
# Processing Record 36 of Set 1 | pimentel
# Processing Record 37 of Set 1 | yarmouth
# Processing Record 38 of Set 1 | east ballina
# Processing Record 39 of Set 1 | antofagasta
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | belyy yar
# Processing Record 42 of Set 1 | badger
# Processing Record 43 of Set 1 | colonia
# Processing Record 44 of Set 1 | kavaratti
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | sume
# Processing Record 47 of Set 1 | blackmans bay
# Processing Record 48 of Set 1 | thunder bay
# Processing Record 49 of Set 1 | ust'-kut
# Processing Record 50 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | terranuova bracciolini
# Processing Record 2 of Set 2 | sitangkai
# Processing Record 3 of Set 2 | dalnegorsk
# Processing Record 4 of Set 2 | smirnovo
# Processing Record 5 of Set 2 | qaqortoq
# Processing Record 6 of Set 2 | kurumkan
# Processing Record 7 of Set 2 | glasgow
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | nadi
# Processing Record 10 of Set 2 | vilyuchinsk
# Processing Record 11 of Set 2 | chelmsford
# Processing Record 12 of Set 2 | isafjordur
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | lazaro cardenas
# Processing Record 16 of Set 2 | lago da pedra
# Processing Record 17 of Set 2 | egilsstadir
# Processing Record 18 of Set 2 | salekhard
# Processing Record 19 of Set 2 | payson
# Processing Record 20 of Set 2 | lubango
# Processing Record 21 of Set 2 | al jubayl
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | stanley
# Processing Record 24 of Set 2 | island harbour
# Processing Record 25 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | tommot
# Processing Record 28 of Set 2 | santana
# Processing Record 29 of Set 2 | pacocha
# Processing Record 30 of Set 2 | hawaiian paradise park
# Processing Record 31 of Set 2 | olonkinbyen
# Processing Record 32 of Set 2 | zeya
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | dudinka
# Processing Record 35 of Set 2 | maine soroa
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | murghob
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | aasiaat
# Processing Record 41 of Set 2 | yorkton
# Processing Record 42 of Set 2 | kingaroy
# Processing Record 43 of Set 2 | watford city
# Processing Record 44 of Set 2 | keflavik
# Processing Record 45 of Set 2 | dolinsk
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | hamilton
# Processing Record 48 of Set 2 | st. john's
# Processing Record 49 of Set 2 | whitehorse
# Processing Record 0 of Set 3 | chonchi
# Processing Record 1 of Set 3 | quesnel
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | toliara
# Processing Record 4 of Set 3 | natal
# Processing Record 5 of Set 3 | lihue
# Processing Record 6 of Set 3 | cloverdale
# Processing Record 7 of Set 3 | tolanaro
# Processing Record 8 of Set 3 | slavyanka
# Processing Record 9 of Set 3 | ust'-ilimsk
# Processing Record 10 of Set 3 | crane
# Processing Record 11 of Set 3 | puerto natales
# Processing Record 12 of Set 3 | remire-montjoly
# Processing Record 13 of Set 3 | oberstaufen
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | mana
# Processing Record 16 of Set 3 | alaghsas
# Processing Record 17 of Set 3 | buloh kasap
# Processing Record 18 of Set 3 | polyarnyy
# Processing Record 19 of Set 3 | chaihe
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | tuscaloosa
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | shangri-la
# City not found. Skipping...
# Processing Record 24 of Set 3 | constantia
# Processing Record 25 of Set 3 | harbin
# Processing Record 26 of Set 3 | nouadhibou
# Processing Record 27 of Set 3 | portland
# Processing Record 28 of Set 3 | herkimer
# Processing Record 29 of Set 3 | namibe
# Processing Record 30 of Set 3 | bor
# Processing Record 31 of Set 3 | smithers
# Processing Record 32 of Set 3 | aykhal
# Processing Record 33 of Set 3 | polysayevo
# Processing Record 34 of Set 3 | kosti
# Processing Record 35 of Set 3 | wailua homesteads
# Processing Record 36 of Set 3 | paita
# Processing Record 37 of Set 3 | nguigmi
# Processing Record 38 of Set 3 | dezhou
# Processing Record 39 of Set 3 | sinabang
# Processing Record 40 of Set 3 | vorgashor
# Processing Record 41 of Set 3 | haiku-pauwela
# Processing Record 42 of Set 3 | la rinconada
# Processing Record 43 of Set 3 | amahai
# Processing Record 44 of Set 3 | balkanabat
# Processing Record 45 of Set 3 | muli
# Processing Record 46 of Set 3 | zhezkent
# Processing Record 47 of Set 3 | puerto baquerizo moreno
# Processing Record 48 of Set 3 | tsiombe
# Processing Record 49 of Set 3 | tanah rata
# Processing Record 0 of Set 4 | jaworzyna slaska
# Processing Record 1 of Set 4 | ust-nera
# Processing Record 2 of Set 4 | yokadouma
# Processing Record 3 of Set 4 | mont-dore
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | minas de marcona
# Processing Record 6 of Set 4 | kayangel
# Processing Record 7 of Set 4 | susuman
# Processing Record 8 of Set 4 | xinyuan
# Processing Record 9 of Set 4 | cascais
# Processing Record 10 of Set 4 | college
# Processing Record 11 of Set 4 | klyuchi
# Processing Record 12 of Set 4 | edinburgh of the seven seas
# Processing Record 13 of Set 4 | kirov
# Processing Record 14 of Set 4 | westport
# Processing Record 15 of Set 4 | staraya vichuga
# Processing Record 16 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | qinggang
# Processing Record 19 of Set 4 | udachny
# Processing Record 20 of Set 4 | pak phanang
# Processing Record 21 of Set 4 | pangody
# Processing Record 22 of Set 4 | an nimas
# Processing Record 23 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 24 of Set 4 | lisakovsk
# Processing Record 25 of Set 4 | bodden town
# Processing Record 26 of Set 4 | makokou
# Processing Record 27 of Set 4 | queenstown
# Processing Record 28 of Set 4 | iskateley
# Processing Record 29 of Set 4 | utrik
# Processing Record 30 of Set 4 | mahina
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | boone
# Processing Record 33 of Set 4 | atafu village
# Processing Record 34 of Set 4 | yaren
# Processing Record 35 of Set 4 | hobyo
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | punta arenas
# Processing Record 38 of Set 4 | ta`u
# Processing Record 39 of Set 4 | nykobing sjaelland
# Processing Record 40 of Set 4 | sampit
# Processing Record 41 of Set 4 | tazovsky
# Processing Record 42 of Set 4 | treuenbrietzen
# Processing Record 43 of Set 4 | kapa'a
# Processing Record 44 of Set 4 | nikolayevsk-on-amure
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | arai
# Processing Record 47 of Set 4 | kilindoni
# Processing Record 48 of Set 4 | brookings
# Processing Record 49 of Set 4 | katiola
# Processing Record 0 of Set 5 | thompson
# Processing Record 1 of Set 5 | malinao ilaya
# Processing Record 2 of Set 5 | eyl
# Processing Record 3 of Set 5 | cedeira
# Processing Record 4 of Set 5 | i-n-salah
# Processing Record 5 of Set 5 | dzhalagash
# Processing Record 6 of Set 5 | kristiansund
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | dubbo
# Processing Record 9 of Set 5 | pinckneyville
# Processing Record 10 of Set 5 | kimbe
# Processing Record 11 of Set 5 | naze
# Processing Record 12 of Set 5 | ariquemes
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | sal rei
# Processing Record 15 of Set 5 | sparta
# Processing Record 16 of Set 5 | taroudant
# Processing Record 17 of Set 5 | ordynskoye
# Processing Record 18 of Set 5 | ellsworth
# Processing Record 19 of Set 5 | umarga
# Processing Record 20 of Set 5 | tshabong
# Processing Record 21 of Set 5 | vorkuta
# Processing Record 22 of Set 5 | zouerate
# Processing Record 23 of Set 5 | chegdomyn
# Processing Record 24 of Set 5 | praia da vitoria
# Processing Record 25 of Set 5 | xunchang
# Processing Record 26 of Set 5 | palikir - national government center
# Processing Record 27 of Set 5 | muang phonsavan
# Processing Record 28 of Set 5 | gandajika
# Processing Record 29 of Set 5 | thinadhoo
# Processing Record 30 of Set 5 | phang nga
# Processing Record 31 of Set 5 | saipan
# Processing Record 32 of Set 5 | mugia
# Processing Record 33 of Set 5 | ghat
# Processing Record 34 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 37 of Set 5 | mejit
# Processing Record 38 of Set 5 | vernon
# Processing Record 39 of Set 5 | bag
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | scarborough
# Processing Record 42 of Set 5 | brisas de zicatela
# Processing Record 43 of Set 5 | vila franca do campo
# Processing Record 44 of Set 5 | tromso
# Processing Record 45 of Set 5 | arraial do cabo
# Processing Record 46 of Set 5 | dese
# Processing Record 47 of Set 5 | charters towers
# Processing Record 48 of Set 5 | shache
# Processing Record 49 of Set 5 | fort bragg
# Processing Record 0 of Set 6 | arkhangel'sk
# Processing Record 1 of Set 6 | abraham's bay
# City not found. Skipping...
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | mount isa
# Processing Record 4 of Set 6 | ganye
# Processing Record 5 of Set 6 | elmendorf air force base
# City not found. Skipping...
# Processing Record 6 of Set 6 | agat village
# Processing Record 7 of Set 6 | punta del este
# Processing Record 8 of Set 6 | lupiro
# Processing Record 9 of Set 6 | cockburn town
# Processing Record 10 of Set 6 | kurmuk
# Processing Record 11 of Set 6 | bantogon
# Processing Record 12 of Set 6 | betio village
# Processing Record 13 of Set 6 | vangaindrano
# Processing Record 14 of Set 6 | timimoun
# Processing Record 15 of Set 6 | ao luek
# Processing Record 16 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 17 of Set 6 | lao cai
# Processing Record 18 of Set 6 | buzuluk
# Processing Record 19 of Set 6 | menongue
# Processing Record 20 of Set 6 | nova vicosa
# Processing Record 21 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 22 of Set 6 | kaifeng
# Processing Record 23 of Set 6 | gafanha da nazare
# Processing Record 24 of Set 6 | turkmenbasy
# Processing Record 25 of Set 6 | filadelfia
# Processing Record 26 of Set 6 | port isabel
# Processing Record 27 of Set 6 | brazzaville
# Processing Record 28 of Set 6 | barinas
# Processing Record 29 of Set 6 | sao joao da barra
# Processing Record 30 of Set 6 | steubenville
# Processing Record 31 of Set 6 | saraqib
# Processing Record 32 of Set 6 | bardai
# Processing Record 33 of Set 6 | suntar
# Processing Record 34 of Set 6 | cam ranh
# Processing Record 35 of Set 6 | catriel
# Processing Record 36 of Set 6 | monywa
# Processing Record 37 of Set 6 | gobabis
# Processing Record 38 of Set 6 | al ghayzah
# Processing Record 39 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 40 of Set 6 | port augusta
# Processing Record 41 of Set 6 | papao
# Processing Record 42 of Set 6 | mogocha
# Processing Record 43 of Set 6 | serowe
# Processing Record 44 of Set 6 | mar del plata
# Processing Record 45 of Set 6 | yuzhno-kurilsk
# Processing Record 46 of Set 6 | kingston
# Processing Record 47 of Set 6 | amos
# Processing Record 48 of Set 6 | kasli
# Processing Record 49 of Set 6 | akureyri
# Processing Record 0 of Set 7 | port moresby
# Processing Record 1 of Set 7 | fale old settlement
# Processing Record 2 of Set 7 | altai
# Processing Record 3 of Set 7 | safotu
# Processing Record 4 of Set 7 | igarka
# Processing Record 5 of Set 7 | altay
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | fort st. john
# Processing Record 8 of Set 7 | douz
# Processing Record 9 of Set 7 | christchurch
# Processing Record 10 of Set 7 | verkhnevilyuysk
# Processing Record 11 of Set 7 | moyynkum
# Processing Record 12 of Set 7 | taoudenni
# Processing Record 13 of Set 7 | nova sintra
# Processing Record 14 of Set 7 | lospalos
# Processing Record 15 of Set 7 | undurkhaan
# Processing Record 16 of Set 7 | port mathurin
# Processing Record 17 of Set 7 | saint-pierre
# Processing Record 18 of Set 7 | broken hill
# Processing Record 19 of Set 7 | yreka
# Processing Record 20 of Set 7 | hanceville
# Processing Record 21 of Set 7 | tympaki
# Processing Record 22 of Set 7 | kolonia town
# Processing Record 23 of Set 7 | businga
# Processing Record 24 of Set 7 | onsala
# Processing Record 25 of Set 7 | sovetskiy
# Processing Record 26 of Set 7 | bikenibeu village
# Processing Record 27 of Set 7 | el calafate
# Processing Record 28 of Set 7 | chicoana
# Processing Record 29 of Set 7 | bocas del toro
# Processing Record 30 of Set 7 | mammoth lakes
# Processing Record 31 of Set 7 | northam
# Processing Record 32 of Set 7 | alvorada
# Processing Record 33 of Set 7 | margate
# Processing Record 34 of Set 7 | chacabuco
# Processing Record 35 of Set 7 | galveston
# Processing Record 36 of Set 7 | atasu
# Processing Record 37 of Set 7 | vilyuysk
# Processing Record 38 of Set 7 | midvagur
# Processing Record 39 of Set 7 | mudgal
# Processing Record 40 of Set 7 | silver springs
# Processing Record 41 of Set 7 | vadso
# Processing Record 42 of Set 7 | mugumu
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | mahdia
# Processing Record 45 of Set 7 | el bauga
# Processing Record 46 of Set 7 | bu'aale
# Processing Record 47 of Set 7 | el alto
# Processing Record 48 of Set 7 | chajari
# Processing Record 49 of Set 7 | katsuura
# Processing Record 0 of Set 8 | chhor
# Processing Record 1 of Set 8 | mollendo
# Processing Record 2 of Set 8 | greymouth
# Processing Record 3 of Set 8 | kasangulu
# Processing Record 4 of Set 8 | rolla
# Processing Record 5 of Set 8 | west hollywood
# Processing Record 6 of Set 8 | treasure island
# Processing Record 7 of Set 8 | capayan
# Processing Record 8 of Set 8 | lorengau
# Processing Record 9 of Set 8 | bambari
# Processing Record 10 of Set 8 | garissa
# Processing Record 11 of Set 8 | kutahya
# Processing Record 12 of Set 8 | touros
# Processing Record 13 of Set 8 | aktanysh
# Processing Record 14 of Set 8 | kerikeri
# Processing Record 15 of Set 8 | tanout
# Processing Record 16 of Set 8 | dubna
# Processing Record 17 of Set 8 | las khorey
# Processing Record 18 of Set 8 | choibalsan
# Processing Record 19 of Set 8 | hami
# Processing Record 20 of Set 8 | guanica
# Processing Record 21 of Set 8 | timbuktu
# Processing Record 22 of Set 8 | san luis
# Processing Record 23 of Set 8 | cafayate
# Processing Record 24 of Set 8 | curumani
# Processing Record 25 of Set 8 | kulgam
# Processing Record 26 of Set 8 | kargasok
# Processing Record 27 of Set 8 | krasnokamensk
# Processing Record 28 of Set 8 | lata
# Processing Record 29 of Set 8 | koubia
# Processing Record 30 of Set 8 | kodiak
# Processing Record 31 of Set 8 | tokonou
# Processing Record 32 of Set 8 | saudarkrokur
# Processing Record 33 of Set 8 | rikaze
# Processing Record 34 of Set 8 | puerto aysen
# Processing Record 35 of Set 8 | puerto ayacucho
# Processing Record 36 of Set 8 | tofol
# Processing Record 37 of Set 8 | sundumbili
# Processing Record 38 of Set 8 | chinde
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | dongola
# Processing Record 41 of Set 8 | nagqu
# Processing Record 42 of Set 8 | morehead city
# Processing Record 43 of Set 8 | dhidhdhoo
# Processing Record 44 of Set 8 | luchegorsk
# Processing Record 45 of Set 8 | selfoss
# Processing Record 46 of Set 8 | saldanha
# Processing Record 47 of Set 8 | enewetak
# Processing Record 48 of Set 8 | manokwari
# Processing Record 49 of Set 8 | kargil
# Processing Record 0 of Set 9 | callao
# Processing Record 1 of Set 9 | rio tinto
# Processing Record 2 of Set 9 | nemuro
# Processing Record 3 of Set 9 | mareeba
# Processing Record 4 of Set 9 | minab
# Processing Record 5 of Set 9 | sarai
# Processing Record 6 of Set 9 | shira
# Processing Record 7 of Set 9 | el porvenir
# Processing Record 8 of Set 9 | nuku'alofa
# Processing Record 9 of Set 9 | swift current
# Processing Record 10 of Set 9 | zaragoza
# Processing Record 11 of Set 9 | zambezi
# Processing Record 12 of Set 9 | san antonio de pale
# Processing Record 13 of Set 9 | happy valley-goose bay
# Processing Record 14 of Set 9 | rivne
# Processing Record 15 of Set 9 | lys'va
# Processing Record 16 of Set 9 | vila velha
# Processing Record 17 of Set 9 | morondava
# Processing Record 18 of Set 9 | mumbwa
# Processing Record 19 of Set 9 | lerwick
# Processing Record 20 of Set 9 | barra de santo antonio
# Processing Record 21 of Set 9 | agustin codazzi
# Processing Record 22 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 23 of Set 9 | carupano
# Processing Record 24 of Set 9 | lodja
# Processing Record 25 of Set 9 | ghanzi
# Processing Record 26 of Set 9 | tame
# Processing Record 27 of Set 9 | puquio
# Processing Record 28 of Set 9 | kokpekty
# Processing Record 29 of Set 9 | berezovyy
# Processing Record 30 of Set 9 | puerto leguizamo
# Processing Record 31 of Set 9 | olinda
# Processing Record 32 of Set 9 | masterton
# Processing Record 33 of Set 9 | tshikapa
# Processing Record 34 of Set 9 | choma
# Processing Record 35 of Set 9 | bontoc
# Processing Record 36 of Set 9 | whitby
# Processing Record 37 of Set 9 | chibougamau
# Processing Record 38 of Set 9 | huarmey
# Processing Record 39 of Set 9 | urangan
# Processing Record 40 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 9 | lampa
# Processing Record 42 of Set 9 | qianzhou
# Processing Record 43 of Set 9 | konarka
# Processing Record 44 of Set 9 | dibba al-hisn
# Processing Record 45 of Set 9 | eksjo
# City not found. Skipping...
# Processing Record 46 of Set 9 | afaahiti
# Processing Record 47 of Set 9 | chilecito
# Processing Record 48 of Set 9 | kegen
# Processing Record 49 of Set 9 | harper
# Processing Record 0 of Set 10 | weatherford
# Processing Record 1 of Set 10 | daru
# Processing Record 2 of Set 10 | vilhena
# Processing Record 3 of Set 10 | aswan
# Processing Record 4 of Set 10 | qarazhal
# Processing Record 5 of Set 10 | senanga
# Processing Record 6 of Set 10 | khandyga
# Processing Record 7 of Set 10 | cambria
# Processing Record 8 of Set 10 | port blair
# Processing Record 9 of Set 10 | mirnyy
# Processing Record 10 of Set 10 | madimba
# Processing Record 11 of Set 10 | luderitz
# Processing Record 12 of Set 10 | lapy
# Processing Record 13 of Set 10 | taltal
# Processing Record 14 of Set 10 | saldus
# Processing Record 15 of Set 10 | juan griego
# Processing Record 16 of Set 10 | celestun
# Processing Record 17 of Set 10 | anna regina
# Processing Record 18 of Set 10 | bontang
# Processing Record 19 of Set 10 | new norfolk
# Processing Record 20 of Set 10 | pudozh
# Processing Record 21 of Set 10 | gizo
# Processing Record 22 of Set 10 | gokwe
# Processing Record 23 of Set 10 | eynesil
# Processing Record 24 of Set 10 | nogliki
# Processing Record 25 of Set 10 | kununurra
# Processing Record 26 of Set 10 | penzance
# Processing Record 27 of Set 10 | prokuplje
# Processing Record 28 of Set 10 | kone
# Processing Record 29 of Set 10 | praia
# Processing Record 30 of Set 10 | sabzevar
# Processing Record 31 of Set 10 | dalbandin
# Processing Record 32 of Set 10 | weno
# Processing Record 33 of Set 10 | carutapera
# Processing Record 34 of Set 10 | horta
# Processing Record 35 of Set 10 | flin flon
# Processing Record 36 of Set 10 | nelson bay
# Processing Record 37 of Set 10 | howard springs
# Processing Record 38 of Set 10 | myeik
# Processing Record 39 of Set 10 | north nowra
# Processing Record 40 of Set 10 | nouna
# Processing Record 41 of Set 10 | bucerias
# Processing Record 42 of Set 10 | az zulfi
# Processing Record 43 of Set 10 | mino
# Processing Record 44 of Set 10 | leh
# Processing Record 45 of Set 10 | nyurba
# Processing Record 46 of Set 10 | nar'yan-mar
# Processing Record 47 of Set 10 | nola
# Processing Record 48 of Set 10 | ulsteinvik
# Processing Record 49 of Set 10 | ilha de mocambique
# Processing Record 0 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 1 of Set 11 | nkurenkuru
# City not found. Skipping...
# Processing Record 2 of Set 11 | sao jose da coroa grande
# Processing Record 3 of Set 11 | carauari
# Processing Record 4 of Set 11 | koungheul
# Processing Record 5 of Set 11 | bolvadin
# Processing Record 6 of Set 11 | qarchi gak
# Processing Record 7 of Set 11 | bengkulu
# Processing Record 8 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 9 of Set 11 | isangel
# Processing Record 10 of Set 11 | ayorou
# Processing Record 11 of Set 11 | la mira
# Processing Record 12 of Set 11 | dolbeau-mistassini
# Processing Record 13 of Set 11 | kenai
# Processing Record 14 of Set 11 | yeppoon
# Processing Record 15 of Set 11 | sabang
# Processing Record 16 of Set 11 | ephrata
# Processing Record 17 of Set 11 | guerrero negro
# Processing Record 18 of Set 11 | camana
# Processing Record 19 of Set 11 | salinas
# Processing Record 20 of Set 11 | sittwe
# Processing Record 21 of Set 11 | tazacorte
# Processing Record 22 of Set 11 | karema
# Processing Record 23 of Set 11 | breaux bridge
# Processing Record 24 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 25 of Set 11 | qujing
# Processing Record 26 of Set 11 | acarau
# Processing Record 27 of Set 11 | motegi
# Processing Record 28 of Set 11 | misratah
# Processing Record 29 of Set 11 | richards bay
# Processing Record 30 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 31 of Set 11 | hotan
# Processing Record 32 of Set 11 | slobodskoy
# Processing Record 33 of Set 11 | san julian
# Processing Record 34 of Set 11 | namtsy
# Processing Record 35 of Set 11 | pacific grove
# Processing Record 36 of Set 11 | mili
# Processing Record 37 of Set 11 | nadym
# Processing Record 38 of Set 11 | greenville
# Processing Record 39 of Set 11 | xihe
# Processing Record 40 of Set 11 | madang
# Processing Record 41 of Set 11 | whitecourt
# Processing Record 42 of Set 11 | tandil
# Processing Record 43 of Set 11 | magnitka
# Processing Record 44 of Set 11 | uturoa
# Processing Record 45 of Set 11 | onguday
# Processing Record 46 of Set 11 | mitu
# Processing Record 47 of Set 11 | patacamaya
# Processing Record 48 of Set 11 | toulepleu guere
# Processing Record 49 of Set 11 | komarichi
# Processing Record 0 of Set 12 | al mindak
# Processing Record 1 of Set 12 | north branford
# Processing Record 2 of Set 12 | saynshand
# Processing Record 3 of Set 12 | campamento
# Processing Record 4 of Set 12 | kesinga
# Processing Record 5 of Set 12 | san patricio
# Processing Record 6 of Set 12 | san nicolas
# Processing Record 7 of Set 12 | usinsk
# Processing Record 8 of Set 12 | cavalaire-sur-mer
# Processing Record 9 of Set 12 | la tuque
# Processing Record 10 of Set 12 | salinopolis
# Processing Record 11 of Set 12 | swakopmund
# Processing Record 12 of Set 12 | manismata
# Processing Record 13 of Set 12 | chadron
# Processing Record 14 of Set 12 | mexico
# Processing Record 15 of Set 12 | beinamar
# Processing Record 16 of Set 12 | aleg
# Processing Record 17 of Set 12 | aktau
# Processing Record 18 of Set 12 | bouza
# Processing Record 19 of Set 12 | zhangatas
# Processing Record 20 of Set 12 | khorixas
# Processing Record 21 of Set 12 | oranjemund
# Processing Record 22 of Set 12 | abashiri
# Processing Record 23 of Set 12 | ensenada
# Processing Record 24 of Set 12 | marang
# Processing Record 25 of Set 12 | sao vicente
# Processing Record 26 of Set 12 | gopalpur
# Processing Record 27 of Set 12 | tongouson
# Processing Record 28 of Set 12 | sao desiderio
# Processing Record 29 of Set 12 | narayanpet
# Processing Record 30 of Set 12 | la punta
# Processing Record 31 of Set 12 | ponta delgada
# Processing Record 32 of Set 12 | mariental
# Processing Record 33 of Set 12 | baillif
# Processing Record 34 of Set 12 | muhos
# Processing Record 35 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 36 of Set 12 | zuyevka
# Processing Record 37 of Set 12 | simpang
# Processing Record 38 of Set 12 | beira
# Processing Record 39 of Set 12 | sultanah
# Processing Record 40 of Set 12 | mukalla
# Processing Record 41 of Set 12 | guiren
# Processing Record 42 of Set 12 | la ronge
# Processing Record 43 of Set 12 | arthur's town
# City not found. Skipping...
# Processing Record 44 of Set 12 | la peca
# Processing Record 45 of Set 12 | saposoa
# Processing Record 46 of Set 12 | lagoa
# Processing Record 47 of Set 12 | cedar city
# Processing Record 48 of Set 12 | marka
# Processing Record 49 of Set 12 | waltrop
# Processing Record 0 of Set 13 | iglino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     albany  42.6001  -73.9662     15.51        65          41        2.97
# 1      sitka  57.0531 -135.3300     13.94        67         100       10.80
# 2    matoury   4.8483  -52.3317     28.98        74           0        2.57
# 3  jamestown  42.0970  -79.2353     13.80        67           0        4.12
# 4    ushuaia -54.8000  -68.3000      8.81        56          20       15.20
#
#   Country        Date
# 0      US  1697148257
# 1      US  1697148270
# 2      GF  1697148270
# 3      US  1697148035
# 4      AR  1697148237

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data2/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data2/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           albany  42.6001  -73.9662     15.51        65          41
# 1            sitka  57.0531 -135.3300     13.94        67         100
# 2          matoury   4.8483  -52.3317     28.98        74           0
# 3        jamestown  42.0970  -79.2353     13.80        67           0
# 4          ushuaia -54.8000  -68.3000      8.81        56          20
#
#          Wind Speed Country        Date
# City_ID
# 0              2.97      US  1697148257
# 1             10.80      US  1697148270
# 2              2.57      GF  1697148270
# 3              4.12      US  1697148035
# 4             15.20      AR  1697148237

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_col = city_data_df["Lat"]
temp_col = city_data_df["Max Temp"]
plt.scatter(lat_col, temp_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_col = city_data_df["Lat"]
humid_col = city_data_df["Humidity"]
plt.scatter(lat_col, humid_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_col = city_data_df["Lat"]
cloud_col = city_data_df["Cloudiness"]
plt.scatter(lat_col, cloud_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_col = city_data_df["Lat"]
wind_col = city_data_df["Wind Speed"]
plt.scatter(lat_col, wind_col, c="c", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2023-10-12)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data2/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_regress(df, col1, col2):
    x = df[col1]
    y = df[col2]
    plt.scatter(x, y)
    plt.xlabel(col1)
    plt.ylabel(col2)
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    regress_values = slope*x + intercept
    plt.plot(x, regress_values, c="r")
    plt.annotate(f"y = {round(slope, 2)} + {round(intercept, 2)}", xy = (0.12, 0.12), xycoords="axes fraction", c="r", size=14)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df["
x = df.loc["Lat"]
y = df["Max Temp"]
plot_regress(x_y)

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
